# %%
import pandas as pd

# %%
df = pd.read_csv('Data/fantasy_league_data/players_teams_stats.csv')
stats_of_players = []
for team in df.Team.unique():
    team_df = df[df['Team'] == team]
    for player in team_df.Player.unique():
        player_stats = team_df[team_df['Player'] == player]
        stats_of_players.append([team, player, player_stats.Actual_Points.mean(), player_stats.Projected_Points.mean(), player_stats.Position.values[0], len(player_stats)])

# %%
stats_of_players_df = pd.DataFrame(stats_of_players)
stats_of_players_df.columns = ['Team', 'Player', 'Average Scored Points', 'Average Projected Points', 'Position', 'Length of Ownership']
stats_of_players_df['Residual'] = stats_of_players_df['Average Scored Points'] - stats_of_players_df['Average Projected Points']
stats_of_players_df.to_csv('Data/fantasy_league_data/Average_Points_By_Ownership.csv')
stats_of_players_df
# Out:
#                     Team               Player  Average Scored Points  \
# 0    Couv Reigning Champ          Dalvin Cook              11.958824
# 1    Couv Reigning Champ        D'Andre Swift              15.350000
# 2    Couv Reigning Champ     Javonte Williams              14.650000
# 3    Couv Reigning Champ  Michael Pittman Jr.              12.305882
# 4    Couv Reigning Champ        Jaylen Waddle              16.523529
# ..                   ...                  ...                    ...
# 374    P-Town CASH KEVIN           Tyler Boyd               8.166667
# 375    P-Town CASH KEVIN         Daniel Jones              24.640000
# 376    P-Town CASH KEVIN      Riley Patterson               2.000000
# 377    P-Town CASH KEVIN         Raiders D/ST               4.000000
# 378    P-Town CASH KEVIN     Chase McLaughlin               4.000000
#
#      Average Projected Points Position  Length of Ownership  Residual
# 0                   14.872353       RB                   17 -2.913529
# 1                   11.129000       RB                   10  4.221000
# 2                   15.650000       RB                    4 -1.000000
# 3                   11.857059       WR                   17  0.448824
# 4                   12.740588       WR                   17  3.782941
# ..                        ...      ...                  ...       ...
# 374                  9.680000       WR                    6 -1.513333
# 375                 17.530000       QB                    1  7.110000
# 376                  5.013333        K                    3 -3.013333
# 377                  5.520000     D/ST                    4 -1.520000
# 378                  7.830000        K                    2 -3.830000
#
# [379 rows x 7 columns]
